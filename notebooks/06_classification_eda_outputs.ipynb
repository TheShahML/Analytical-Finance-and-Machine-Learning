# %% [markdown]
# # 06 Classification EDA Outputs
#
# EDA and figures for outputs of **04_buyback_announcement_classification_ollama.ipynb** (LLM labels, validation samples, checkpoint runs).
#
# **Inputs (typical):** classification CSVs or JSON written by notebook04 (e.g. validation batches, full run checkpoints).
#
# **Outputs:** tables and plots under `outputs/eda/classification/` (create that directory in the notebook or via `Path.mkdir`).
#
# This notebook is a scaffold—add cells for distributions, label balance, confusion-style summaries, and agreement checks once your classification artifacts are fixed.

# %%
from __future__ import annotations

from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(f"Project root: {PROJECT_ROOT}")
