# %% [markdown]
# # 03 Keyword and Theme Exploration
#
# ## Purpose
#
# This notebook explores interpretable keyword and theme patterns in the validated transcript dataset.
#
# ## Source Modules and Functions Used
#
# - expected to use `src/features/keyword_counts.py`
# - expected to use `src/utils/paths.py`
# - any reusable theme dictionaries or stable helpers should live in `src/`
#
# ## Expected Inputs
#
# - the usable transcript dataset written by Notebook 01
# - candidate keyword sets for exploratory theme analysis
#
# ## Outputs Written
#
# - keyword summary tables to `outputs/tables/`
# - exploratory figures to `outputs/figures/`
# - outputs should also be shown directly in the notebook

# %%
from __future__ import annotations

import os
import sys
from pathlib import Path

# Make the repository root importable so `src/` works in Jupyter.
NOTEBOOK_DIR = Path.cwd()
PROJECT_ROOT_CANDIDATES = [NOTEBOOK_DIR, NOTEBOOK_DIR.parent]
PROJECT_ROOT = next(
    (candidate for candidate in PROJECT_ROOT_CANDIDATES if (candidate / "src").exists()),
    None,
)
if PROJECT_ROOT is None:
    raise RuntimeError("Could not locate the repository root containing `src/`.")
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
os.chdir(PROJECT_ROOT)

from src.utils.paths import ensure_project_dirs

ensure_project_dirs()
print(f"Project root: {PROJECT_ROOT}")
